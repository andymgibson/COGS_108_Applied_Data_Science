# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Andrew Gibson
# - Sofia Morales-Fermin
# - Samantha Lincoln
# - Nayana Naineni
# - Ananya Wasker

# %% [markdown]
# # Research Question

# %% [markdown]
# -  Question: (1) Does the predictive power of cardiovascular risk factors (e.g., BMI, BP, cholesterol) differ between patients with and without diabetes?
# We plan on investigating disease-specific risk modeling, important for individualized care. (2) Among individuals without a reported history of heart disease, can we use their profiles to identify those at "high-risk", and investigate whether certain factors may be protective (e.g., excercise)?
# We plan on exploring protective factors in "resilient" individuals and determining if there is a discernible “high-risk” group in not CVD patients.
#
# -  Variables: -Q1- Independent: Diabetes, Dependents: Risk factors: BMI, BP, cholesterol, etc.; -Q2- Independents: Protective factors: i.e. exercise, good sleep hygiene, Dependents: high-risk group(s)

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# **Background Research: Scientific Publications**
#
# Cardiovascular disease (CVD) remains a leading cause of morbidity and mortality globally, with traditional risk factors such as high cholesterol, elevated BMI, hypertension, diabetes, smoking, and lack of exercise widely acknowledged as significant contributors. A study analyzing patients' knowledge of cardiovascular risk factors found that only about a third could correctly identify all the key health factors influencing cardiovascular health, highlighting substantial gaps in public awareness. Importantly, the study noted that patients with diabetes were more aware of their increased risk, although a significant portion (approximately 20%) remained unaware that diabetes itself is a risk factor for heart disease (Wartak et al., 2011).
#
# Research has demonstrated variability in the predictive power of traditional risk factors depending on diabetic status. Echouffo-Tcheugui and Kengne (2013) reviewed multiple risk assessment models and observed a potential advantage for diabetes-specific models over models based on the general population. Their analysis indicated that models developed specifically for diabetics, such as UKPDS and ADVANCE, often provided more accurate risk predictions in diabetic patients, emphasizing the importance of making predictive tools disease-specific.
#
# Further, a body of research has shown that not all individuals with diabetes experience the same level of cardiovascular risk. In 2015, Rana et al. found significant differences in CHD risk among diabetic individuals based on diabetes duration and presence of other cardiovascular risk factors, challenging the notion that diabetes alone confers a CHD risk equivalent to having prior coronary disease. This distinction is crucial for identifying high-risk groups without reported heart disease but whose risk profiles resemble those who have already experienced cardiac events.
#
# These findings support our investigation into whether the predictive power of traditional cardiovascular risk factors differs based on diabetic status, and whether we can identify "resilient" individuals – those who remain heart disease-free despite having high-risk profiles. Addressing these questions could enhance targeted preventive strategies and refine individualized patient care.
#
# Sources:
# - Wartak et al., 2011: https://www.sciencedirect.com/science/article/pii/S0002914911003353
# - Echouffo-Tcheugui and Kengne, 2013: https://www.sciencedirect.com/science/article/pii/S1262363613001298
# - Rana et al., 2015: https://link.springer.com/article/10.1007/s11606-015-3556-3
#
# **Background Research: Other Data Science Projects**
#
# Aravind Pillai’s Kaggle notebook “Cardiac Disease Prediction with TabNet Deep Learn” applies TabNet architecture, which is a deep-learning model tailored for tabular data, and it was used to analyze the Cleveland heart-disease data set. The study preprocesses standard clinical features to train TabNet with k-fold cross-validation and report the model’s accuracy to be 80-82%. While the study shows that deep models are effective at capturing non-linear interactions from various risk-factors, the cohort group is treated as homogenous and does not evaluate performance separately from patients with or without diabetes. Moreover, the study also does not account for individuals that do not have any diseases despite having high-risk characteristics. The feature-ranking approach would be a great method to adopt for this project as it suggests a way to compare variability across subgroups. Furthermore, the analysis of the project could greatly benefit from making stratification models by diabetic status and then exploring groups with high-risk profiles but that do not have CVD.
#
# Mario Caesar’s Kaggle notebook “Listen to Your Heart: A Disease Prediction” uses more traditional machine learning tools such as exploratory analysis, feature engineering, and ensemble classifiers on the same data set. The model was able to achieve accuracies of about 85-88%. The EDA uses correlations among BMI, max heart rate, and chest pain type, and the feature-selection process using established thresholds, like considering individuals with cholesterol greater than 240 mg/dL with elevated CVD risk. On the other hand, Caesar’s analysis focuses on overall prediction but does not account for subgroup differences or protective factors. This approach highlights the critical role of thorough EDA and how ensemble models can boost overall prediction accuracy. In contrast, our study looks at how those same risk factors manifest differently for patients with and without diabetes.
#
# While Echouffo-Tcheugui and Kengne found that diabetes-specific cohorts often show improved calibration with data sets that only include diabetics, this method loses accuracy when applied to a more general population, where only a minority of the population has diabetes. This highlights concerns about overfitting and overgeneralizing when models are trained with just diabetic profiles. Moreover, much of the existing evidence is derived from observational cohorts, which puts models at potential risk of confounding variables such as variations in lifestyle, eating habits, comorbidities, etc. Inconsistencies in how certain key variables are measured highlights the importance of differencing results obtained from rigorous studies versus anecdotal examples. By critically evaluating these differing viewpoints and weighing how different methods can be applied to the data, we can ensure that the data is being analyzed using robust and reproducible evidence rather than unverified assumptions, like assuming that individuals with high cholesterol are at higher risk of having diabetes. This balanced perspective will strengthen the credibility of our findings.
#
# Sources:
# - Aravind Pillai, “Cardiac Disease Prevention with TabNet Deep Learn,” https://www.kaggle.com/code/aspillai/cardiac-disease-prediction-with-tabnet-deep-learn/notebook. Accessed April 29, 2025.
# - Mario Ceasar, “Listen to Your Heart: A Disease Prediction,”  https://www.kaggle.com/code/caesarmario/listen-to-your-heart-a-disease-prediction. Accessed April 29, 2025.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# For the first research question, we hypothesize that the predictive power of traditional cardiovascular risk factors such as BMI, blood pressure, and cholesterol levels will differ significantly between diabetic and non-diabetic individuals. Since diabetes is a chronic, metabolic disease that specifically affects the heart (among other organs) and is a severe risk to heart health, we expect these factors to have significantly stronger predictive associations with heart disease in non-diabetic patients when compared to diabetic patients and therefore better predictive power.
#
# For the second research question, for individuals without a reported history of heart disease, we hypothesize that some subsets of people will, in fact, exhibit high-risk profiles based on their health and lifestyle data in the given dataset. We expect that protective factors such as frequent physical activity, healthy diet, or lower stress levels will be more common in these “resilient” high-risk individuals, serving as a buffer against disease development. Inversely, we hypothesize that individuals who do not have a history of heart disease but do exhibit less activity, high cholesterol, high stress levels, and other significant traits indicative of declining health are more susceptible to heart diseases developing in the future, which we want to predict from the dataset.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Overview
#
#  - Dataset Name: Heart Disease Data for Health Research
#
#  - Link: https://www.kaggle.com/datasets/oktayrdeki/heart-disease
#
#  - Number of Observations: 10,000
#
#  - Number of variables: 21
#
# To answer our research questions, we needed access to a wide variety of data that captures not only the demographic and behavioural information of people’s lives but also physical indicators of any disease in order to create a complete, holistic picture of a person’s health. Since this dataset has 2 groups of patients (those that do and don’t have diabetes) it helps us answer the first half of our research question in order to conduct disease-specific risk modelling. Additionally, since the dataset also contains data about various risk factors that would be used in creating patient health profiles for those without heart disease, it would help in answering the second half of our aforementioned research question.
#
# Firstly, the dataset includes thousands of data points relating to information about traditional cardiovascular risk factors like smoking, exercise, blood pressure, BMI, and cholesterol levels as well as a wide range of other factors like family history of disease, sugar consumption etc. The massive dataset consists of detailed numerical continuous data (for variables like blood pressure, fasting blood sugar etc.), categorical ordinal data (ranking exercise, sleep, stress etc. as low, medium, high quality) as well as categorical binary data (for variables like ‘has diabetes’, ‘does smoke’). However, since we are only looking into how the predictive power of a few factors varies between diabetic and non-diabetic people, we only need information on the specific risk factors, a person’s diabetic status, and their heart disease status. Each relevant variable / risk factor used to compare diabetics / non-diabetics is described below:
#
#  - ID: reported patient ID to record each row (the index of the dataset, integers)
#
#  - Blood Pressure: the individual’s reported systolic blood pressure (float)
#
#  - Cholesterol Level: the individual’s reported cholesterol level, which comes from adding up their HDL level, their LDL level, and 20% of their triglyceride level (float)
#
#  - Diabetes: the individual’s reported diabetes status, varies between Yes and No (currently string data type, can be converted to ‘True’ and ‘False’ boolean data type for easier data processing)
#
#  - BMI: the individual’s reported body mass index (float)

# %% [markdown]
# ## Dataset: Heart Disease Data for Health Research

# %%
import pandas as pd
heart_disease_dataset = pd.read_csv(r'data/heart_disease.csv')
heart_disease_dataset.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %% [markdown]
# ## Data Cleaning:
#
# ### Dropping irrelevant columns
#
# Since our research question focuses on predictive features such as `BMI`, `Blood Pressure`, and `Cholesterol Level` as well as `Diabetes` and `Heart Disease Status`, we will focus on these columns from the dataset.

# %%
columns = ['BMI', 'Blood Pressure', 'Cholesterol Level', 'Diabetes', 'Heart Disease Status']
heart_disease_dataset = heart_disease_dataset[columns]
heart_disease_dataset.columns
# Out:
# Index(['BMI', 'Blood Pressure', 'Cholesterol Level', 'Diabetes',
#        'Heart Disease Status'],
#       dtype='object')

# %% [markdown]
# ### Dropping Null Values

# %%
heart_disease_dataset.isna().any()
# Out:
# BMI                      True
# Blood Pressure           True
# Cholesterol Level        True
# Diabetes                 True
# Heart Disease Status    False
# dtype: bool

# %% [markdown]
# Here, we can observe that most of our columns include `NaN` values so we will drop them to make it easier to work with.

# %%
heart_disease_dataset = heart_disease_dataset.dropna(how='any')

# %% [markdown]
# ### Checking data types of columns:

# %%
heart_disease_dataset.dtypes
# Out:
# BMI                     float64
# Blood Pressure          float64
# Cholesterol Level       float64
# Diabetes                 object
# Heart Disease Status     object
# dtype: object

# %% [markdown]
# Since `Heart Disease Status` and `Diabetes` is stored as an object, we will convert them to Boolean values in order to perform mathematical calculations.

# %%
heart_disease_dataset['Heart Disease Status'] = heart_disease_dataset['Heart Disease Status'].str.lower().map({'yes': True, 'no': False})
heart_disease_dataset['Diabetes'] = heart_disease_dataset['Diabetes'].str.lower().map({'yes': True, 'no': False})

# %% [markdown]
# ### Checking for outliers in data
# As there are limitations for `BMI`, `Blood Pressure`, and `Cholesterol Level` values, we will check if the dataset contains reasonable numerical information.

# %%
heart_disease_dataset['BMI'].describe()
# Out:
# count    9899.000000
# mean       29.078131
# std         6.300650
# min        18.002837
# 25%        23.664021
# 50%        29.088412
# 75%        34.509014
# max        39.996954
# Name: BMI, dtype: float64

# %% [markdown]
# Here, we can see that the maximum BMI is around 40 and the minimum is around 18 which aligns with the typical range.

# %%
heart_disease_dataset['Blood Pressure'].describe()
# Out:
# count    9899.000000
# mean      149.772906
# std        17.569903
# min       120.000000
# 25%       134.000000
# 50%       150.000000
# 75%       165.000000
# max       180.000000
# Name: Blood Pressure, dtype: float64

# %% [markdown]
# Here, we can see that the maximum systolic blood pressure is around 180 and the minimum is around 120 which is within the possible range.

# %%
heart_disease_dataset['Cholesterol Level'].describe()
# Out:
# count    9899.000000
# mean      225.412769
# std        43.573888
# min       150.000000
# 25%       187.000000
# 50%       226.000000
# 75%       263.000000
# max       300.000000
# Name: Cholesterol Level, dtype: float64

# %% [markdown]
# This level is the total amount of cholesterol (the sum of LDL and HDL) and since it ranges from 150 to 300, this is a reasonable set of values.
#
#
# ## Exploratory Data Analysis
#
# ### Visualization
#
# Now let's visualize the numerical columns through Violin Plots to understand the distribution of values for our dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

visualize_cols = ['BMI', 'Blood Pressure', 'Cholesterol Level']

melted_df = heart_disease_dataset.melt(value_vars=visualize_cols, var_name='', value_name='Value')

plt.figure(figsize=(10, 6))
sns.violinplot(x='', y='Value', data=melted_df, hue='', palette='Set1')
plt.title('Violin plots of BMI, Blood Pressure, and Cholesterol Level')
plt.show()

# %% [markdown]
# ### Differentiating Diabetics VS Non-Diabetics
#
# Let's use SeaBorn heatmaps to glean some basic insights on how differently risk factors manifest in diabetic vs non-diabetic patients. We use heatmaps particularly to uncover health patterns in both groups while also understanding the strength of correlations between the variables and the target (diabetics vs non diabetics).

# %%
df_diabetic = heart_disease_dataset[heart_disease_dataset['Diabetes'] == True]
df_nondiabetic = heart_disease_dataset[heart_disease_dataset['Diabetes'] == False]

plt.figure(figsize=(10, 8))
sns.heatmap(df_diabetic.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap - Diabetics")
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(df_nondiabetic.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap - Non-Diabetics")
plt.show()

# %% [markdown]
# ### Note on Data Integrity
#
# As we can see from the above correlation heatmaps for both diabetic and non-diabetic individuals, we observe that the correlation matrices are identical or nearly identical across all variables. This is highly unusual and statistically improbable in real-world health data, as we expect physiological patterns to differ between these two groups. This concern is investigated and discussed in the 'Ethics and Privacy' section of our data.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# When researching our heart disease risk model, we carefully considered ethical concerns that could come up throughout our project. Since our research questions focus on traditional risk factors such as BMI and diabetes, there is a risk of reinforcing overgeneralizations or biases toward individuals based on these features. Although our dataset is from Kaggle,which is a widely accepted resource among data scientists, it doesn't specify if informed consent was obtained, which does raise potential privacy concerns. We do acknowledge that the dataset may contain biases related to gender or age representation that may affect our model. To address these concerns, we avoid deterministic language (e.g., saying someone "should have" heart disease).
#
# Unfortunately, our dataset does not mention many demographic characteristics like race or socioeconomic status, and we cannot conclude whether or not certain populations were excluded. In terms of gender, we see a 50-50 split between Male and Female, with 0% other which could be a limitation as only binary gender categories are included. Age appears to be equally distributed from participants ranging from 18 to 80 years old and approximately 1000 individuals from each 6 year sub-group (ie. 18-24). Our dataset does not specify its source which hinders us from understanding any potential biases it may contain. Moreover, a diagnosis for heart disease requires the availability of care facilities which may exclude certain individuals.
#
# In order to detect these biases, we will stratify analyses by their columns to check if model performance varies. We will also utilize evaluation criteria such as precision or recall to ensure equity. When communicating our analysis, we will report any biases found and the limitations of such to prevent inaccurate findings.
#
# Due to the medical nature of our data, there are many privacy risks that arise, however, given that our dataset does not contain any personal information regarding the individuals from which the medical data was collected, we are able to avoid this.
#
# In our project proposal we rather prophetically remarked, “It is worth noting that we could not locate a license for Oktay Ördekçi’s heart disease dataset despite his specifying that the license is ‘Other (specified in description)’” which unfortunately we later discovered was only the tip of the bullshit iceberg.
#
# Our early EDA efforts revealed a number of concerning features of this Kaggle dataset (the first and primary of our two aforementioned datasets). Sofía initially noticed that there were a number of entries that didn’t make sense from a medical standpoint. For example, one row mentions a subject with a fasted blood sugar of 160 mg/dL, but for “Diabetes Yes/No” it said “No” which is almost impossible. The Mayo Clinic says, “fasting blood sugar level from 100 to 125 mg/dL (5.6 to 6.9 mmol/L) is considered prediabetes. If it's 126 mg/dL (7 mmol/L) or higher on two separate tests, you have diabetes.” Andrew pointed out that, while highly unlikely, it was possible that factors, such as sleep, exercise, diet, etc. could have caused a fluke test and of course two tests are required to diagnose diabetes. We were at first hesitant to invalidate this dataset given it was the only one that perfectly met our requirements and research questions, but the mounting evidence made it clear the dataset was entirely fabricated.
#
# When we loaded the data in a dataframe and began to do descriptive and exploratory analysis, we noticed that BMI represented an almost rectangular distribution. This is highly unusual because BMI is a classic example of a normal distribution. While of course there will always be some sampling variability, there are 10,000 rows in this dataset and so it’s inconceivable that they could have ethically sampled real data in a way that would yield such an unnatural distribution. There were also other clues, such as it said 51% of the sample were smokers – whereas 11.6% of the US population are smokers. Finally, when we started creating more visualizations, such as heatmaps and violin plots showing differences in our cardiac risk factors, it was clear that the data was fabricated, because on the violin plot BMI is a tiny, cramped distribution and on the heatmap for diabetes and non-diabetes the correlation matrices for the are nearly identical which is statistically improbable with any sample of real-world health data. While it is possible that heart disease risk factors would actually be the same between diabetes and non-diabetes groups (see sources for background research), it is nearly impossible that all of the markers would be the same.
#
# These glaring discrepancies mean we will be changing datasets for the next checkpoint, but given we just found out about this falsification (over 90 people have cited/used this dataset), Prof. Fleischer said we could stick with this dataset for this checkpoint and discuss our argument for its invalidity.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * (1) Communication: Based on technology requirements, we have determined that Instagram messages (commonly referred to as DMs) to communicate as a team. We will use this to plan group meetings and most importantly to schedule git commits so we do not create conflicts in the code.
# * (2) Tone: Direct, but considerate of others opinions and beliefs.
# * (3) Decision-Making:  Decision-making will be done through majority vote. If a teammate does not respond in a reasonable time, the rest of the group will move forward with the decision.
# * (4) Tasks, Division of Labor, and Specialization: Tasks will be chosen by specialization or by interest. We will update our shared Google Doc to track tasks and who is working on them.
# * (5) Schedule and Deadlines: Meetings will be scheduled based on availability and planned through group chats.
# * (6) Adherence Policies for Struggling Group Members: Members should reach out if falling behind or struggling. Team members will help or reassign tasks if needed.
# * (7) Check the #rules channel in our group Discord to stay updated on team expectations.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time | Completed Before Meeting | Discuss at Meeting |
# |---|---|---|---|
# | 4/9  | 4pm  | Create Instagram Group chat, Discord and establish group synergy and communication. | Review past projects and research different interests for potential projects. |
# | 4/17  | 5pm  | Brainstorm topic ideas and prepare a list. | Decide on a specific area of research and come up with potential research questions. |
# | 4/21  | 4pm  | Look for relevant datasets. | Find datasets and make our topic more specific. Allocate work for project review. |
# | 4/29  | 5:30pm  | Look over expectations of course, collect more datasets. | Finalize research question and dataset. Allocate work for project proposal. |
# | 5/9  | 5pm  | Submit project proposal, work on feedback, implement changes! | Create project plan and framework. (Was rescheduled)|
# | 5/13 | 5pm  | Allocate project sections to different members and begin work. | Work together to finish EDA and visualizations, descriptive analysis. Discussed issues with source of current dataset. |
# | 5/15  | 5pm  | Think of ways to use the Yes/No data in the new CDC dataset. | Meet again to discuss using new dataset as well as descriptive analysis and EDA |
# | 5/20  | 2pm  | Determine approaches to finding correlations between variables and dependent. | Members work together to finish correlation section with different methods to determine relationship between variables. |
# | 5/21  | 2pm  | Members work on brainstorming modelling approaches for predictive modelling. | Code and implement predictive baseline and advanced models. Review performance and tune/refine based on results. |
# | 5/25  | 2pm  | Begin drafting final results and conclusions. | Discuss interpretations of results, check all code thoroughly, finalize plots/visualizations. Do necessary write-ups for all sections of project and draft final report. |
# | 6/1  | 2pm  | Complete given checklist for project. | Complete the 5 minute video, submit on Github! |
